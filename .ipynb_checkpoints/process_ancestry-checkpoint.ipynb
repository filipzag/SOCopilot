# %%
from elasticsearch import Elasticsearch
import urllib3
import pandas as pd
import warnings
from flatten_json import flatten
from helpers import LinkedList
import os


ELASTIC_PASS = os.environ["ES_PASS"]
NODES = [
    "https://esh1p:9200",
    "https://esh2p:9200",
    
]
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# **Connect to Elasticsearch**

# %%
es = Elasticsearch(NODES,
    basic_auth=("elastic", ELASTIC_PASS),
    verify_certs=False                       
)
# Out:
# /home/filipzag/.local/lib/python3.9/site-packages/elasticsearch/_sync/client/__init__.py:395: SecurityWarning: Connecting to 'https://esh1p:9200' using TLS with verify_certs=False is insecure
#   _transport = transport_class(
# /home/filipzag/.local/lib/python3.9/site-packages/elasticsearch/_sync/client/__init__.py:395: SecurityWarning: Connecting to 'https://esh2p:9200' using TLS with verify_certs=False is insecure
#   _transport = transport_class(

# %% [markdown]
# **Get data**

# %%
process_id = "8980"
index_pattern = "windows"
process_eid = "{f97bd2d6-b164-6393-040c-000000006c00}"
host_name = "WKSIBUDIMLIC.corp.diverto.hr"

q_str = 'event.code: 1 AND host.name: "{}" AND proces.entity_id: "{}"'.format(host_name, process_eid)


## Linked list of linked processes
linked_processes = LinkedList()


def  get_parent_process(process_eid):
    q_str = 'event.code: 1 AND host.name: "{}" AND process.entity_id: "{}"'.format(host_name, process_eid)
    
    response = es.search(index=index_pattern,
          query={"query_string": {
                   "query": q_str }},source = [ "process.name", "process.entity_id", "process.parent.entity_id"] 
          )
    
    if len(response['hits']['hits']) > 0:
        
        linked_processes.insert(response['hits']['hits'][0]['_source']['process']['name'])
        
        
        if response['hits']['hits'][0]['_source']['process']['parent']:
            
            get_parent_process(response['hits']['hits'][0]['_source']['process']['parent']['entity_id'])
        
        
        
get_parent_process(process_eid)

# %% [markdown]
# **Print process ancestry**

# %%
node = linked_processes.get_head()

while node != None:
    if node.get_next() == None:
        print(node.get_data(),end = "")
    else:
    
        print( node.get_data(),end = " => ")
    node = node.get_next()
# Out:
# smss.exe => smss.exe => wininit.exe => services.exe => svchost.exe => raserver.exe

# %% [markdown]
# **Process tree**

# %%
from helpers2 import Process


process_list = []


process_id = "8980"
index_pattern = "windows"
process_eid = "{f97bd2d6-b164-6393-040c-000000006c00}"
host_name = "WKSIBUDIMLIC.corp.diverto.hr"

q_str = 'event.code: 1 AND host.name: "{}" AND proces.entity_id: "{}"'.format(host_name, process_eid)




def get_child_process(process):
    
    
    q_str = 'event.code: 1 AND host.name: "{}" AND process.parent.entity_id: "{}"'.format(host_name, process.get_id())
    
    response = es.search(index=index_pattern,
          query={"query_string": {
                   "query": q_str }},source = [ "process.name", "process.entity_id", "process.parent.entity_id"] 
          )
    
    
    if len(response['hits']['hits']) > 0:
        
        for event in response['hits']['hits']:
                
            process.add_child(event['_source']['process']['name'])
            
            new_process = Process(event['_source']['process']['name'], event['_source']['process']['entity_id'], event['_source']['process']['parent']['entity_id'])
            print(event['_source']['process']['name'])
            process_list.append(new_process)
            
            get_child_process(new_process)

            
            

def  get_parent_process(process_eid):
    
    
    q_str = 'event.code: 1 AND host.name: "{}" AND process.entity_id: "{}"'.format(host_name, process_eid)
    
    response = es.search(index=index_pattern,
          query={"query_string": {
                   "query": q_str }},source = [ "process.name", "process.entity_id", "process.parent.entity_id"] 
          )
    
    if len(response['hits']['hits']) > 0:
        
        
        new_process = Process(response['hits']['hits'][0]['_source']['process']['name'], response['hits']['hits'][0]['_source']['process']['entity_id'], response['hits']['hits'][0]['_source']['process']['parent']['entity_id'])
        
        process_list.append(new_process)
        get_child_process(new_process)
        
                
        
        if response['hits']['hits'][0]['_source']['process']['parent']:
            
            get_parent_process(response['hits']['hits'][0]['_source']['process']['parent']['entity_id'])
        
        
        
get_parent_process(process_eid)





            
            
for proc in process_list:
    print(proc.get_id())
# Out:
# gpupdate.exe
# powershell.exe
# gpupdate.exe
# powershell.exe
# raserver.exe
# taskhostw.exe
# taskhostw.exe
# taskhostw.exe
# gpupdate.exe
# gpupdate.exe
# svchost.exe
# gpscript.exe
# svchost.exe
# svchost.exe
# svchost.exe
# svchost.exe
# svchost.exe
# svchost.exe
# TrustedInstaller.exe
# svchost.exe
# svchost.exe
# services.exe
# svchost.exe
# gpscript.exe
# svchost.exe
# svchost.exe
# svchost.exe
# svchost.exe
# svchost.exe
# svchost.exe
# TrustedInstaller.exe
# svchost.exe
# svchost.exe
# lsass.exe
# wininit.exe
# services.exe
# svchost.exe
# gpscript.exe
# svchost.exe
# svchost.exe
# svchost.exe
# svchost.exe
# svchost.exe
# svchost.exe
# TrustedInstaller.exe
# svchost.exe
# svchost.exe
# lsass.exe
# csrss.exe
# smss.exe
# wininit.exe
# services.exe
# svchost.exe
# gpscript.exe
# svchost.exe
# svchost.exe
# svchost.exe
# svchost.exe
# svchost.exe
# svchost.exe
# TrustedInstaller.exe
# svchost.exe
# svchost.exe
# lsass.exe
# csrss.exe
# autochk.exe
# smss.exe
# csrss.exe
# winlogon.exe
# LogonUI.exe
# dwm.exe
# userinit.exe
# explorer.exe
# EXCEL.EXE
# splwow64.exe
# msedge.exe
# msedge.exe
# EXCEL.EXE
# EXCEL.EXE
# SecurityHealthSystray.exe
# KeePass.exe
# msedge.exe
# msedge.exe
# msedge.exe
# msedge.exe
# msedge.exe
# msedge.exe
# msedge.exe
# msedge.exe
# msedge.exe
# msedge.exe
# msedge.exe
# Update.exe
# Teams.exe
# Teams.exe
# Teams.exe
# Teams.exe
# Teams.exe
# Teams.exe
# Teams.exe
# Teams.exe
# Teams.exe
# Teams.exe
# Teams.exe
# SACMonitor.exe
# openvpn-gui.exe
# openvpn.exe
# {f97bd2d6-b164-6393-040c-000000006c00}
# {f97bd2d6-de12-6392-3900-000000006c00}
# {f97bd2d6-f34a-6392-7103-000000006c00}
# {f97bd2d6-f37c-6392-7c03-000000006c00}
# {f97bd2d6-efc6-6392-3403-000000006c00}
# {f97bd2d6-eff7-6392-3f03-000000006c00}
# {f97bd2d6-f003-6392-4103-000000006c00}
# {f97bd2d6-f6fb-6392-a303-000000006c00}
# {f97bd2d6-1470-6393-9d05-000000006c00}
# {f97bd2d6-15a8-6393-a305-000000006c00}
# {f97bd2d6-1d7a-6393-0306-000000006c00}
# {f97bd2d6-1d8f-6393-0706-000000006c00}
